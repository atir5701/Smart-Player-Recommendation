# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
data=pd.read_csv("dataDraft1.csv")
data.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value Preferred Foot    Position  ...  Penalties  \
# 0         FC Barcelona  110500.0           Left     Forward  ...       75.0
# 1             Juventus   77000.0          Right     Forward  ...       85.0
# 2  Paris Saint-Germain  118500.0          Right     Forward  ...       81.0
# 3    Manchester United   72000.0          Right          GK  ...       40.0
# 4      Manchester City  102000.0          Right  MidFielder  ...       79.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0       96.0     33.0            28.0           26.0       6.0        11.0
# 1       95.0     28.0            31.0           23.0       7.0        11.0
# 2       94.0     27.0            24.0           33.0       9.0         9.0
# 3       68.0     15.0            21.0           13.0      90.0        85.0
# 4       88.0     68.0            58.0           51.0      15.0        13.0
#
#    GKKicking  GKPositioning  GKReflexes
# 0       15.0           14.0         8.0
# 1       15.0           14.0        11.0
# 2       15.0           15.0        11.0
# 3       87.0           88.0        94.0
# 4        5.0           10.0        13.0
#
# [5 rows x 46 columns]

# %%
potentail_overall=data.iloc[:,[4,5]]
potentail_overall.head()
# Out:
#    Overall  Potential
# 0       94         94
# 1       94         94
# 2       92         93
# 3       91         93
# 4       91         92

# %%
# clustering level 1
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
kmeans=KMeans(n_clusters=3).fit(potentail_overall)
labels=pd.DataFrame(kmeans.labels_)
labels.head()
# Out:
#    0
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
# Mapping for good ,medium and avg player to corresponding indexs

dic={}
dic['good']=0
dic['avg']=7650
dic['poor']=17750
dic
# Out:
# {'good': 0, 'avg': 7650, 'poor': 17750}

# %%
# finding the cluster id of the players
good=labels.iloc[dic['good'],0]
avg=labels.iloc[dic['avg'],0]
poor=labels.iloc[dic['poor'],0]

# %%
t1=(labels==good)
t2=(labels==poor)
t3=(labels==avg)
t2=t2.to_numpy()
t3=t3.to_numpy()
t1=t1.to_numpy()
print(len(t1),len(t2),len(t3))
# Out:
# 17918 17918 17918

# %%
indgood=[]
indavg=[]
indpoor=[]
for i in range(len(t1)):
    if t1[i][0]==True:
        indgood.append(i)
    elif t2[i][0]==True:
        indpoor.append(i)
    else:
        indavg.append(i)

good_players=data.iloc[indgood,:]
avg_players=data.iloc[indavg,:]
poor_players=data.iloc[indpoor,:]

# %%
#good_players.head()
#avg_players
poor_players.head()
# Out:
#           ID           Name  Age Nationality  Overall  Potential  \
# 9770  186112      J. Akinde   28     England       65         65
# 9771  200449    D. McGregor   32    Scotland       65         65
# 9774  236545  Teixeira José   28      Brazil       65         65
# 9775  188417   A. Fernández   32     Uruguay       65         65
# 9780  156675   A. Considine   31    Scotland       65         65
#
#                        Club  Value Preferred Foot    Position  ...  Penalties  \
# 9770           Lincoln City  550.0          Right     Forward  ...       70.0
# 9771              Hibernian  300.0          Right    Defender  ...       43.0
# 9774        Pohang Steelers  425.0          Right    Defender  ...       36.0
# 9775  San Martin de Tucumán  400.0          Right  MidFielder  ...       59.0
# 9780               Aberdeen  350.0           Left    Defender  ...       38.0
#
#       Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 9770       58.0     37.0            33.0           31.0      12.0        15.0
# 9771       63.0     59.0            66.0           63.0      11.0        12.0
# 9774       62.0     60.0            64.0           60.0       7.0        10.0
# 9775       65.0     45.0            53.0           46.0       8.0         8.0
# 9780       64.0     67.0            67.0           65.0       8.0        15.0
#
#       GKKicking  GKPositioning  GKReflexes
# 9770        6.0           14.0        16.0
# 9771       10.0           16.0        10.0
# 9774        9.0           11.0         5.0
# 9775        6.0           11.0        13.0
# 9780       12.0           11.0        10.0
#
# [5 rows x 46 columns]

# %%
# PCA Clusetring In good Players

pca = PCA(n_components=3)
pca_g = pca.fit_transform(good_players.iloc[:,10:])
goodplayers = pd.DataFrame(pca_g)

kmeans_good=KMeans(n_clusters=4).fit(goodplayers)
good_labels=pd.DataFrame(kmeans_good.labels_)
good_labels.head()
# Out:
#    0
# 0  3
# 1  3
# 2  3
# 3  1
# 4  0

# %%
good_players_dic={}
good_players_dic['Forward']=0
good_players_dic['GK']=3
good_players_dic["MidFielder"]=4
good_players_dic["Defender"]=44

good_players_dic
# Out:
# {'Forward': 0, 'GK': 3, 'MidFielder': 4, 'Defender': 44}

# %%
# finding the cluster id of the players
frw=good_labels.iloc[good_players_dic['Forward'],0]
gk=good_labels.iloc[good_players_dic['GK'],0]
mid=good_labels.iloc[good_players_dic['MidFielder'],0]
defe=good_labels.iloc[good_players_dic['Defender'],0]

frw=(good_labels==frw)
gk=(good_labels==gk)
mid=(good_labels==mid)
defe=(good_labels==defe)

frw=frw.to_numpy()
gk=gk.to_numpy()
mid=mid.to_numpy()
defe=defe.to_numpy()

print(len(frw),len(gk),len(defe),len(mid))
# Out:
# 3776 3776 3776 3776

# %%
indgoodfrw=[]
indgoodgk=[]
indgooddefe=[]
indgoodmid=[]

for i in range(len(frw)):
    if frw[i][0]==True:
        indgoodfrw.append(i)
    elif gk[i][0]==True:
        indgoodgk.append(i)
    elif defe[i][0]==True:
        indgooddefe.append(i)
    else:
        indgoodmid.append(i)

good_forwards=good_players.iloc[indgoodfrw,:]
good_defenders=good_players.iloc[indgooddefe,:]
good_midfielders=good_players.iloc[indgoodmid,:]
good_gk=good_players.iloc[indgoodgk,:]

# %%
#good_gk
#good_midfielders
#good_defenders
#good_forwards

# %%
# PCA Clusetring In Avg Players

pca = PCA(n_components=3)
pca_a = pca.fit_transform(avg_players.iloc[:,10:])
avgplayers = pd.DataFrame(pca_a)

kmeans_avg=KMeans(n_clusters=4).fit(avgplayers)
avg_labels=pd.DataFrame(kmeans_avg.labels_)
avg_labels.head()
# Out:
#    0
# 0  0
# 1  1
# 2  3
# 3  3
# 4  3

# %%
avg_players.iloc[10,:10]
# Out:
# ID                          150278
# Name                     J. Drobný
# Age                             38
# Nationality         Czech Republic
# Overall                         73
# Potential                       73
# Club              SV Werder Bremen
# Value                        270.0
# Preferred Foot               Right
# Position                        GK
# Name: 2588, dtype: object

# %%
# Id of players

avg_players_dic={}
avg_players_dic['Forward']=1 # set
avg_players_dic['GK']=10
avg_players_dic["MidFielder"]=3# set
avg_players_dic["Defender"]=0

avg_players_dic
# Out:
# {'Forward': 1, 'GK': 10, 'MidFielder': 3, 'Defender': 0}

# %%
# finding the cluster id of the players
frw=avg_labels.iloc[avg_players_dic['Forward'],0]
gk=avg_labels.iloc[avg_players_dic['GK'],0]
mid=avg_labels.iloc[avg_players_dic['MidFielder'],0]
defe=avg_labels.iloc[avg_players_dic['Defender'],0]

frw=(avg_labels==frw)
gk=(avg_labels==gk)
mid=(avg_labels==mid)
defe=(avg_labels==defe)

frw=frw.to_numpy()
gk=gk.to_numpy()
mid=mid.to_numpy()
defe=defe.to_numpy()

print(len(frw),len(gk),len(defe),len(mid))
# Out:
# 8554 8554 8554 8554

# %%
indavgfrw=[]
indavggk=[]
indavgdefe=[]
indavgmid=[]

for i in range(len(frw)):
    if frw[i][0]==True:
        indavgfrw.append(i)
    elif gk[i][0]==True:
        indavggk.append(i)
    elif defe[i][0]==True:
        indavgdefe.append(i)
    else:
        indavgmid.append(i)

avg_forwards=avg_players.iloc[indavgfrw,:]
avg_defenders=avg_players.iloc[indavgdefe,:]
avg_midfielders=avg_players.iloc[indavgmid,:]
avg_gk=avg_players.iloc[indavggk,:]

# %%
# avg_gk
# avg_midfielders
# # avg_forwards
# # avg_defenders

# %%
# PCA Clusetring In Poor Players

pca = PCA(n_components=3)
pca_p = pca.fit_transform(poor_players.iloc[:,10:])
poorplayers = pd.DataFrame(pca_p)

kmeans_poor=KMeans(n_clusters=4).fit(poorplayers)
poor_labels=pd.DataFrame(kmeans_poor.labels_)
poor_labels.head()
# Out:
#    0
# 0  2
# 1  3
# 2  0
# 3  0
# 4  3

# %%
poor_players.iloc[1,:10]
# 0
# Out:
# ID                     200449
# Name              D. McGregor
# Age                        32
# Nationality          Scotland
# Overall                    65
# Potential                  65
# Club                Hibernian
# Value                   300.0
# Preferred Foot          Right
# Position             Defender
# Name: 9771, dtype: object

# %%
# Id of players

poor_players_dic={}
poor_players_dic['Forward']=0
poor_players_dic['GK']=12
poor_players_dic["MidFielder"]=3
poor_players_dic["Defender"]=1

poor_players_dic
# Out:
# {'Forward': 0, 'GK': 12, 'MidFielder': 3, 'Defender': 1}

# %%
# finding the cluster id of the players
frw=poor_labels.iloc[poor_players_dic['Forward'],0]
gk=poor_labels.iloc[poor_players_dic['GK'],0]
mid=poor_labels.iloc[poor_players_dic['MidFielder'],0]
defe=poor_labels.iloc[poor_players_dic['Defender'],0]

frw=(poor_labels==frw)
gk=(poor_labels==gk)
mid=(poor_labels==mid)
defe=(poor_labels==defe)

frw=frw.to_numpy()
gk=gk.to_numpy()
mid=mid.to_numpy()
defe=defe.to_numpy()

print(len(frw),len(gk),len(defe),len(mid))
# Out:
# 5588 5588 5588 5588

# %%
indpoorfrw=[]
indpoorgk=[]
indpoordefe=[]
indpoormid=[]

for i in range(len(frw)):
    if frw[i][0]==True:
        indpoorfrw.append(i)
    elif gk[i][0]==True:
        indpoorgk.append(i)
    elif defe[i][0]==True:
        indpoordefe.append(i)
    else:
        indpoormid.append(i)

poor_forwards=poor_players.iloc[indpoorfrw,:]
poor_defenders=poor_players.iloc[indpoordefe,:]
poor_midfielders=poor_players.iloc[indpoormid,:]
poor_gk=poor_players.iloc[indpoorgk,:]

# %%
poor_gk
poor_midfielders
poor_forwards
poor_defenders
# Out:
#            ID              Name  Age          Nationality  Overall  Potential  \
# 9771   200449       D. McGregor   32             Scotland       65         65
# 9780   156675      A. Considine   31             Scotland       65         65
# 9787   230404  Benjamin Muscato   26               Brazil       65         65
# 9788   180740  N. Topor-Stanley   33            Australia       65         65
# 9797   203015     Lee Woong Hee   29       Korea Republic       65         65
# ...       ...               ...  ...                  ...      ...        ...
# 17907  238477       K. Fujikawa   19                Japan       47         61
# 17910  244677      M. Baldisimo   18               Canada       47         69
# 17912  243413          D. Walsh   18  Republic of Ireland       47         68
# 17913  238813      J. Lundstram   19              England       47         65
# 17917  246269         G. Nugent   16              England       46         66
#
#                          Club  Value Preferred Foot    Position  ...  \
# 9771                Hibernian  300.0          Right    Defender  ...
# 9780                 Aberdeen  350.0           Left    Defender  ...
# 9787              Chapecoense  475.0          Right    Defender  ...
# 9788           Newcastle Jets  220.0           Left    Defender  ...
# 9797                 FC Seoul  425.0          Right    Defender  ...
# ...                       ...    ...            ...         ...  ...
# 17907            Júbilo Iwata   60.0          Right  MidFielder  ...
# 17910  Vancouver Whitecaps FC   70.0          Right  MidFielder  ...
# 17912            Waterford FC   60.0           Left    Defender  ...
# 17913         Crewe Alexandra   60.0          Right  MidFielder  ...
# 17917         Tranmere Rovers   60.0          Right  MidFielder  ...
#
#        Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 9771        43.0       63.0     59.0            66.0           63.0      11.0
# 9780        38.0       64.0     67.0            67.0           65.0       8.0
# 9787        66.0       42.0     74.0            66.0           66.0      11.0
# 9788        41.0       61.0     62.0            60.0           57.0      15.0
# 9797        13.0       55.0     58.0            65.0           67.0      12.0
# ...          ...        ...      ...             ...            ...       ...
# 17907       44.0       35.0     41.0            44.0           54.0      10.0
# 17910       36.0       40.0     48.0            49.0           49.0       7.0
# 17912       38.0       43.0     44.0            47.0           53.0       9.0
# 17913       43.0       45.0     40.0            48.0           47.0      10.0
# 17917       33.0       43.0     40.0            43.0           50.0      10.0
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes
# 9771         12.0       10.0           16.0        10.0
# 9780         15.0       12.0           11.0        10.0
# 9787         10.0       13.0           14.0        14.0
# 9788         16.0        8.0           12.0        10.0
# 9797          9.0       12.0           14.0        12.0
# ...           ...        ...            ...         ...
# 17907        12.0        6.0           11.0         8.0
# 17910         7.0        9.0           14.0        15.0
# 17912        10.0        9.0           11.0        13.0
# 17913        13.0        7.0            8.0         9.0
# 17917        15.0        9.0           12.0         9.0
#
# [1432 rows x 46 columns]
